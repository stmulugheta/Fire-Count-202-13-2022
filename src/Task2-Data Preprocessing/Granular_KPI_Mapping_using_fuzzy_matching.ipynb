# %% [markdown]
# # Using Fuzzy Matching with Granular KPI

# %%
from fuzzywuzzy import fuzz
from fuzzywuzzy import process
import pandas as pd
import numpy as np
from joblib import Parallel, delayed

# %% [markdown]
# Reading files
# --

# %%
data_df = pd.read_csv("clean_sentences.csv")
data_df
# Out:
#                                              Sentences
# 0    62.2% use of electricity from renewable_source...
# 1    at present, the energy expenditure has been re...
# 2    170 business leaders call on eu decision-maker...
# 3    taking the tolerance values of the measuring s...
# 4    with the help of energy management, the divisi...
# ..                                                 ...
# 121  a forest plantation managed by new forests in ...
# 122  waste_reduction, recycling business initiative...
# 123  waste_reduction: 71,670 tons/year sugar cane r...
# 124  the amount of fossil-based electricity has bee...
# 125  since 2015, use has been reduced by 26 percent...
#
# [126 rows x 1 columns]

# %%
data_df = data_df[data_df['Sentences'].notna()]
data_df.shape
# Out:
# (126, 1)

# %%
kpi_df = pd.read_csv("GRI KPI list - Granular KPI list.csv")
kpi_df
# Out:
#                                     Description of KPI  \
# 0    Scale of the organization, including: Total nu...
# 1    Scale of the organization, including: total nu...
# 2    Scale of the organization, including: Scale of...
# 3                                                  NaN
# 4    Scale of the organization, including: quantity...
# ..                                                 ...
# 157                                                NaN
# 158  Percentage of new suppliers that were screened...
# 159    Number of suppliers assessed for social impacts
# 160  Number of suppliers identified as having signi...
# 161  Total number of identified leaks, thefts, or l...
#
#                                                    KPI         ESG  category  \
# 0                            total number of employees  Governance    102.07
# 1                           total number of operations  Governance    102.07
# 2                       net sales (for private sector)  Governance    102.07
# 3                     net revenues (for public sector)  Governance    102.07
# 4                                 quantity of products  Governance    102.07
# ..                                                 ...         ...       ...
# 157  percentage of investment agreements that inclu...      Social    412.03
# 158  Percentage of new suppliers that were screened...      Social    414.01
# 159    Number of suppliers assessed for social impacts      Social    414.02
# 160  Number of suppliers having significant actual ...      Social    414.02
# 161  Total number of identified leaks, thefts, or l...      Social    418.01
#
#     gri_disclosure_sub_code
# 0                        ai
# 1                       aii
# 2                      aiii
# 3                      aiii
# 4                        av
# ..                      ...
# 157                       a
# 158                       a
# 159                       a
# 160                       b
# 161                       b
#
# [162 rows x 5 columns]

# %% [markdown]
# Using Fuzzing Logic
# --

# %%
metric = fuzz.token_set_ratio

# %%
sent = np.array(data_df[['Sentences']])
kpi = np.array(kpi_df[["KPI"]])

# %%
#Used Parallel Processing for when we get lots of data
def parallel_fuzzy_match(idxa,idxb):
    return [sent[idxa][0],kpi[idxb][0],metric(sent[idxa][0],kpi[idxb][0])]  
results = Parallel(n_jobs=-1,verbose=1)(delayed(parallel_fuzzy_match)(idx1, idx2) for idx1 in range(len(sent)) for idx2 in range(len(kpi)) \)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=-1)]: Done 10256 tasks      | elapsed:    2.7s
# [Parallel(n_jobs=-1)]: Done 20412 out of 20412 | elapsed:    3.4s finished

# %%
results = pd.DataFrame(results,columns = ["Sentences","KPI","Token_Set_Ratio"])
results
# Out:
#                                                Sentences  \
# 0      62.2% use of electricity from renewable_source...
# 1      62.2% use of electricity from renewable_source...
# 2      62.2% use of electricity from renewable_source...
# 3      62.2% use of electricity from renewable_source...
# 4      62.2% use of electricity from renewable_source...
# ...                                                  ...
# 20407  since 2015, use has been reduced by 26 percent...
# 20408  since 2015, use has been reduced by 26 percent...
# 20409  since 2015, use has been reduced by 26 percent...
# 20410  since 2015, use has been reduced by 26 percent...
# 20411  since 2015, use has been reduced by 26 percent...
#
#                                                      KPI  Token_Set_Ratio
# 0                              total number of employees               48
# 1                             total number of operations               47
# 2                         net sales (for private sector)               26
# 3                       net revenues (for public sector)               27
# 4                                   quantity of products               19
# ...                                                  ...              ...
# 20407  percentage of investment agreements that inclu...               38
# 20408  Percentage of new suppliers that were screened...               36
# 20409    Number of suppliers assessed for social impacts               28
# 20410  Number of suppliers having significant actual ...               34
# 20411  Total number of identified leaks, thefts, or l...               30
#
# [20412 rows x 3 columns]

# %%
results.shape
# Out:
# (20412, 3)

# %%
# Here we are selecting the unique sentences with highest Token Set Ratio.
results = results.sort_values("Token_Set_Ratio", ascending=False)
results = results.drop_duplicates(subset=["Sentences"], keep="first")
results = results.sort_index()
results.shape
# Out:
# (126, 3)

# %%
results
# Out:
#                                                Sentences  \
# 71     62.2% use of electricity from renewable_source...
# 233    at present, the energy expenditure has been re...
# 414    170 business leaders call on eu decision-maker...
# 578    taking the tolerance values of the measuring s...
# 719    with the help of energy management, the divisi...
# ...                                                  ...
# 19693  a forest plantation managed by new forests in ...
# 19915  waste_reduction, recycling business initiative...
# 19943  waste_reduction: 71,670 tons/year sugar cane r...
# 20153  the amount of fossil-based electricity has bee...
# 20251  since 2015, use has been reduced by 26 percent...
#
#                                                      KPI  Token_Set_Ratio
# 71                  amount of energy consumption reduced               89
# 233                 amount of energy consumption reduced               56
# 414              Scope 1 GHG emissions of CO2 equivalent               58
# 578             co2 equivalent of biogenic co2 emissions               64
# 719                 amount of energy consumption reduced               74
# ...                                                  ...              ...
# 19693                             emissions in base year               48
# 19915  Percentage of security personnel who have rece...               42
# 19943                                    operation costs               75
# 20153                             total electricity sold               67
# 20251                         total number of operations               56
#
# [126 rows x 3 columns]

# %%
results.to_csv("Fuzzy_Token Set Ratio_Granular_KPI_Mapping.csv")
