# %% [markdown]
# # Using Fuzzy Matching with Generic KPI

# %%
from fuzzywuzzy import fuzz
from fuzzywuzzy import process
import pandas as pd
import numpy as np
from joblib import Parallel, delayed

# %% [markdown]
# Reading files
# --

# %%
data_df = pd.read_csv("clean_sentences.csv")
data_df
# Out:
#                                              Sentences
# 0    62.2% use of electricity from renewable_source...
# 1    at present, the energy expenditure has been re...
# 2    170 business leaders call on eu decision-maker...
# 3    taking the tolerance values of the measuring s...
# 4    with the help of energy management, the divisi...
# ..                                                 ...
# 121  a forest plantation managed by new forests in ...
# 122  waste_reduction, recycling business initiative...
# 123  waste_reduction: 71,670 tons/year sugar cane r...
# 124  the amount of fossil-based electricity has bee...
# 125  since 2015, use has been reduced by 26 percent...
#
# [126 rows x 1 columns]

# %%
data_df = data_df[data_df['Sentences'].notna()]
data_df.shape
# Out:
# (126, 1)

# %%
kpi_df = pd.read_csv("GRI KPI list - Generic KPI List.csv")
kpi_df
# Out:
#                                   KPI   ESG category
# 0                           employees     Governance
# 1                          operations     Governance
# 2                           net sales     Governance
# 3                        net revenues     Governance
# 4                            products     Governance
# 5                            services     Governance
# 6                   critical concerns     Governance
# 7                        compensation     Governance
# 8                     operation costs       Economic
# 9                      employee wages       Economic
# 10                  employee benefits       Economic
# 11   payments to providers of capital       Economic
# 12  payments to government by country       Economic
# 13              community investments       Economic
# 14                     economic value       Economic
# 15                     monetary value       Economic
# 16                   entry level wage       Economic
# 17                  senior management       Economic
# 18         products purchased locally       Economic
# 19         corruption risk operations       Economic
# 20           anti-corruption policies       Economic
# 21                dismissed employees       Economic
# 22                  business partners       Economic
# 23                      legal actions       Economic
# 24                  third-party sales       Economic
# 25                       transactions       Economic
# 26                        Profit/loss       Economic
# 27               Corporate income tax       Economic
# 28                renewable materials  Environmental
# 29            non-renewable materials  Environmental
# 30                 recycled materials  Environmental
# 31                 reclaimed products  Environmental
# 32                   fuel consumption  Environmental
# 33                 energy consumption  Environmental
# 34                   water withdrawal  Environmental
# 35               freshwater discharge  Environmental
# 36                  water consumption  Environmental
# 37            protected habitat areas  Environmental
# 38             restored habitat areas  Environmental
# 39                      GHG emissions  Environmental
# 40         ozone depleting substances  Environmental
# 41                 organic pollutants  Environmental
# 42              not employee workers          Social
# 43                      working hours         Social
# 44                         fatalities         Social
# 45                           injuries         Social
# 46                     training hours         Social
# 47                    employee salary         Social
# 48          renumeration of employees         Social
# 49        incidents of discrimination         Social
# 50                 security personnel         Social
# 51              human rights policies         Social
# 52            incidents of violations         Social
# 53                          suppliers         Social

# %% [markdown]
# Using Fuzzing Logic
# --

# %%
metric = fuzz.token_set_ratio

# %%
sent = np.array(data_df[['Sentences']])
kpi = np.array(kpi_df[["KPI"]])

# %%
#Used Parallel Processing for when we get lots of data
def parallel_fuzzy_match(idxa,idxb):
    return [sent[idxa][0],kpi[idxb][0],metric(sent[idxa][0],kpi[idxb][0])]  
results = Parallel(n_jobs=-1,verbose=1)(delayed(parallel_fuzzy_match)(idx1, idx2) for idx1 in range(len(sent)) for idx2 in range(len(kpi)) \
                                       )
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=-1)]: Done 6224 tasks      | elapsed:    2.5s
# [Parallel(n_jobs=-1)]: Done 6804 out of 6804 | elapsed:    2.9s finished

# %%
results = pd.DataFrame(results,columns = ["Sentences","KPI","Token_Set_Ratio"])
results
# Out:
#                                               Sentences  \
# 0     62.2% use of electricity from renewable_source...
# 1     62.2% use of electricity from renewable_source...
# 2     62.2% use of electricity from renewable_source...
# 3     62.2% use of electricity from renewable_source...
# 4     62.2% use of electricity from renewable_source...
# ...                                                 ...
# 6799  since 2015, use has been reduced by 26 percent...
# 6800  since 2015, use has been reduced by 26 percent...
# 6801  since 2015, use has been reduced by 26 percent...
# 6802  since 2015, use has been reduced by 26 percent...
# 6803  since 2015, use has been reduced by 26 percent...
#
#                               KPI  Token_Set_Ratio
# 0                       employees               11
# 1                      operations               12
# 2                       net sales               12
# 3                    net revenues               15
# 4                        products               11
# ...                           ...              ...
# 6799  incidents of discrimination               22
# 6800           security personnel               18
# 6801        human rights policies               19
# 6802      incidents of violations               20
# 6803                    suppliers                9
#
# [6804 rows x 3 columns]

# %%
# Here we are selecting the unique sentences with highest Token Set Ratio.
results = results.sort_values("Token_Set_Ratio", ascending=False)
results = results.drop_duplicates(subset=["Sentences"], keep="first")
results = results.sort_index()
results.shape
# Out:
# (126, 3)

# %%
results
# Out:
#                                               Sentences  \
# 32    62.2% use of electricity from renewable_source...
# 87    at present, the energy expenditure has been re...
# 147   170 business leaders call on eu decision-maker...
# 173   taking the tolerance values of the measuring s...
# 249   with the help of energy management, the divisi...
# ...                                                 ...
# 6545  a forest plantation managed by new forests in ...
# 6610  waste_reduction, recycling business initiative...
# 6650  waste_reduction: 71,670 tons/year sugar cane r...
# 6708  the amount of fossil-based electricity has bee...
# 6751  since 2015, use has been reduced by 26 percent...
#
#                                     KPI  Token_Set_Ratio
# 32                     fuel consumption              100
# 87                   energy consumption               50
# 147                       GHG emissions              100
# 173    payments to providers of capital               27
# 249                  energy consumption              100
# ...                                 ...              ...
# 6545   payments to providers of capital               27
# 6610                  business partners               64
# 6650                    operation costs               75
# 6708  payments to government by country               37
# 6751                         operations              100
#
# [126 rows x 3 columns]

# %%
results.to_csv("Fuzzy_Token Set Ratio_Generic_KPI_Mapping.csv")
