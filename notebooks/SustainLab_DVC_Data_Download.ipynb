# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
import getpass

# %%
DAGSHUB_USER_NAME = input("Enter DAGSHub username: ")
DAGSHUB_TOKEN = getpass.getpass('Please enter your DAGsHub token or password: ')
DAGSHUB_REPO_NAME = input("Enter Dagshub Repo: ")
# Out:
# Enter DAGSHub username: sradical
# Please enter your DAGsHub token or password: ··········
# Enter Dagshub Repo: SustainLab

# %%
if '/content/{DAGSHUB_REPO_NAME}':
    % rm -fr SustainLab/

# %%
###
### Need to clone once if new branch or any update to branch 
###
# To clone a branch for specific brancb
#!git clone -b <branch-name> https://{DAGSHUB_USER_NAME}:{DAGSHUB_TOKEN}@dagshub.com/Omdena/{DAGSHUB_REPO_NAME}.git

# To clone master - default option
# !git clone https://{DAGSHUB_USER_NAME}:{DAGSHUB_TOKEN}@dagshub.com/Omdena/{DAGSHUB_REPO_NAME}.git
# !git checkout master
# Out:
# Cloning into 'SustainLab'...
# remote: Enumerating objects: 82, done.
# remote: Counting objects: 100% (82/82), done.
# remote: Compressing objects: 100% (69/69), done.
# remote: Total 82 (delta 33), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (82/82), done.
# fatal: not a git repository (or any of the parent directories): .git

# %%
# %ls /content/
% cd /content/{DAGSHUB_REPO_NAME}
% ls
# Out:
# drive/  sample_data/  SustainLab/
# /content/SustainLab
# data.dvc  notebooks/   pyproject.toml  reports/          src/
# env.yml   poetry.lock  README.md       requirements.txt

# %%
# !git config --global user.name {DAGSHUB_USER_NAME}

# %% [markdown]
# ### DVC data Download

# %%
###
## DVC 
###
dvc_installed = ! pip list -v | grep dvc
if not dvc_installed:
  print("Installing DVC")
  ! pip install dvc >=2.8.1 --quiet

# Import DVC package (relevant only when working in a Colab environment)
import dvc

# Initilize DVC in the local directory
# !dvc init &> /dev/null 

# Track the changes with git
# !git add .dvc .dvcignore .gitignore
# !git commit -m "Initialize DVC"

# Configure DVC
# !dvc remote add -f origin https://dagshub.com/Omdena/{DAGSHUB_REPO_NAME}.dvc # -f forces overwrite if exists
# !dvc remote modify --local origin auth basic
# !dvc remote modify --local origin user {DAGSHUB_USER_NAME}
# !dvc remote modify --local origin password {DAGSHUB_TOKEN}
# !dvc remote default origin

# %%
% ls /content/SustainLab/
# Out:
# data/     env.yml     poetry.lock     README.md  requirements.txt
# data.dvc  notebooks/  pyproject.toml  reports/   src/

# %%
! dvc pull /content/{DAGSHUB_REPO_NAME}/data.dvc >& dev_null
# Out:
# Streaming output truncated to the last 5000 lines.
# 7afc2ecc7b46cc5a2511250e09a079:   0% 0.00/883k [00:00<?, ?B/s{'info': ''}]
#
# !
#   0%|          |0291e8ec679a7e722bbcf4920a078b     0.00/? [00:00<?,        ?B/s]
# 0291e8ec679a7e722bbcf4920a078b:   0% 0.00/4.40M [00:00<?, ?B/s{'info': ''}]
#
# !
#   0%|          |65b3864c2198a9732eb0229a861708     0.00/? [00:00<?,        ?B/s]
# 65b3864c2198a9732eb0229a861708:   0% 0.00/263k [00:00<?, ?B/s{'info': ''}]
#  39% 795/2.03k [00:16<00:29, 42.3file/s{'info': ' /content/SustainLab/data/500-reports-dataset/24107f45-d9bf-42fa-9125-e55e9d501b22.txt |'}]
# !
#   0%|          |9580ad4c82a5762861f9dff20c771d     0.00/? [00:00<?,        ?B/s]
# 9580ad4c82a5762861f9dff20c771d:   0% 0.00/286k [00:00<?, ?B/s{'info': ''}]
#
# !
#   0%|          |3ddfb5e2fc430288b4557a59053949     0.00/? [00:00<?,        ?B/s]
# 3ddfb5e2fc430288b4557a59053949:   0% 0.00/110k [00:00<?, ?B/s{'info': ''}]
#
# !
# ...

# %%
# %ls data/500-reports-dataset/
# Out:
# 010c3e42-f753-47e8-bf0a-e9ed383a215b_entities.csv
# 010c3e42-f753-47e8-bf0a-e9ed383a215b.pdf
# 010c3e42-f753-47e8-bf0a-e9ed383a215b_sent.csv
# 010c3e42-f753-47e8-bf0a-e9ed383a215b_topics.csv
# 010c3e42-f753-47e8-bf0a-e9ed383a215b.txt
# 026fb455-06ec-43cc-a841-d2c49871e708.pdf
# 026fb455-06ec-43cc-a841-d2c49871e708_sent.csv
# 026fb455-06ec-43cc-a841-d2c49871e708_topics.csv
# 026fb455-06ec-43cc-a841-d2c49871e708.txt
# 03bf01ad-7f64-466f-8bc9-00fe76a66ac6.pdf
# 03bf01ad-7f64-466f-8bc9-00fe76a66ac6_sent.csv
# 03bf01ad-7f64-466f-8bc9-00fe76a66ac6_topics.csv
# 03bf01ad-7f64-466f-8bc9-00fe76a66ac6.txt
# 0513bfad-34c5-4367-900b-4fa3dc268b02.pdf
# 0513bfad-34c5-4367-900b-4fa3dc268b02_sent.csv
# 0513bfad-34c5-4367-900b-4fa3dc268b02_topics.csv
# 0513bfad-34c5-4367-900b-4fa3dc268b02.txt
# 051f303a-b6d5-4dac-84a4-ebf40d9a44d7.pdf
# 051f303a-b6d5-4dac-84a4-ebf40d9a44d7_sent.csv
# 051f303a-b6d5-4dac-84a4-ebf40d9a44d7_topics.csv
# 051f303a-b6d5-4dac-84a4-ebf40d9a44d7.txt
# ...
