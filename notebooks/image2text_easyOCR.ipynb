# %%
import PIL
import os 
os.environ['KMP_DUPLICATE_LIB_OK']='True'
from PIL import ImageDraw
im = PIL.Image.open("image.png")
im
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=1 size=1394x909 at 0x2255B36D610>

# %%
import easyocr

# %%
reader = easyocr.Reader(['en']) 
result = reader.readtext('image.png',detail=0)
print(result)
# Out:
# CUDA not available - defaulting to CPU. Note: This module is much faster with a GPU.
# Downloading detection model, please wait. This may take several minutes depending upon your network connection.
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Downloading recognition model, please wait. This may take several minutes depending upon your network connection.
# Progress: |██████████████████████████████████████████████████| 100.0% Complete['MA', 'Moor4c#ou Ordik #DoK', 'BOSKALIS', '{Rora', 'Mask144 rolnrot AMd 14', 'MI IVar Gi#rohmomau #HI84 IHdutJIt.', 'AT', 'GLANCE', '0144 Auoohgoukm {0dinm1*IMX Mor', 'MHLnratM {Ciiatomt I0 a1 (Muanuaaxts', 'a41 WYordJA1', 'sodat *', '370433', 'Ake', '6', 'Mal', 'Hnktd_', 'Dtoptitand', 'Ood', '&adp esonw & &kin dhear~#m6d', 'Tetia', 'mxii', '444 Ant', 'AExt', '{RAn%-', 'Diins 53', '824', 'i45*4Xt', 'RR17 ArE', '0n?us,%47a', 'Jlyn', 'Ainaii #', '407131', '4c Xxick', 'J~npvel~', '{Ahkp Ror', 'ikhnabclo', 'divctsc', 'Rasponsiblc', 'Community', "Un mibriuy' { m53*4", 'AIn *', 'hiist-', '844" 488', 'Gcnts', 'upplict}', 'cnooacatcnt', '#ioaio', '#snvu #~ &', 'Jit:', '3e#4er', 'Via #t+ 100#46', 'VELattr=', 'Taneth', 'tat tttby', 'O# wetttl ##', '#lnt # Qankrar', '{atattt', 'Mt #at#', 'Int RY5', 'Xkn"#t4e', 'Jnetttrtt tita', 'T58teF', 'ttdat', 'Lxitatattun', '#u', '#clak}', '###', 'Lt', '#bttrettramt', 'Latd ~bat', '30', 'S1x Rren:', 'vDT}€', '##oynai, ~K2t', 'Ata', 'Lettate', 'Luetntt', '#linati *9804', '65 #Qhabm', 'Yeakaan', 'Ketedt ##t* #mar', '#net 6a &44', '#*5Ajr', 'Ihehahiiit tx', 'XX01c*7h', '3d2344 Dnhn Dimo', '9o &ou4uae', 'Grst', 'abit IIta #tta', 'tm {Htan', 'tpiearat', '{4it', 'Lotttyat3tta', 'DaRktiint -', '#e tUnt', '137 #trtt # #ui', '1,40 Mrantt', 'Haib 4 #rtytr', '#0ndtt', 'Qntatt', 'Rntest #4tnd', '#aent', '0ueorrt', 'Fadrn', 'reiadt', 'ahaiant', 'Fntato', 'Lintt', 'Cteniretetinns', 'D r', 'Anmr oi', '830#h', 'FEAnX', 'betenal', 'sarute', 'Mrrrn Qti', '##nk }', '38.', '#nata-to', 'Latsalk', '#h:l', '17#4', 'TaIh *', "Yy 'M0T +", 'C', '43t; IT:', 'EKFI:', 'Eaol', 'JiIznusc', '74x=', "Oh'blt", '79men', '4nadadaa', '4gill', '7X48', '#K: =', 'ni4', '0isksusn', '0336; 438\' <> %"aEnf:', 'ZRwS', '1+amloem aVe', '137', '[Xogkane', '3424*7#7', '376xlla}41', '4<n74', '4{44', '~inlot', 'An36f +it', '43f"t-', '066xol', '4vt"', 'Rtibo~7', 'R Ex', '#raF', '#uch', 'AJMB D', '~avamx', 'Gtal', 'IBSMN', 'Z.30 =', 'Mzk*', 'WRer', 's', '147+4004', 'LI', 'ca', '74 Eooie', '04Y.000*+', 'XMrr', '#7enf', '~x~WE', 'RkiAn', '41547F', 'Henoi', 'Ute44;', 'ahey AoovXAXN', 'Saaut', 'RD', 'Jo*5t8', 'Hti: #_', 'acln', 'OoXut  80,', '~a1 {', '38kx', "'4ncol:i:", '58tii8:?_', 'LL* ', 'JAaReS', 'Nenx', 'Bko', 'iols+', 'Aptox', 'ii*Xb', '#us#', '4n~#x', 'J2d -to', '{l', '3*Xi', 'AKhShs>', '238', '6hi', 'X*nu M?', '4i" 3tc', '#74in3tt', 'Xlt', "0x Roi'Tntelia:_", '#Apile:', '"88 #pkxunin', 'LSiilue', '3I58744', '+ N4i', 'Gkia', '3:n; >', '~K0 4#o n=', '#+t', 'Jon3id', 'Ivdk', '#st #xi:', '4axu:e.+f #wi:', 'jupekxuuksr', 'UMSizls}', '48 +:', '1r}hA', '20', 'Xtt', 'obe7t', 'Gilnd', 'A3nin: < 7#838', 'Iini', 'IESMN', 'Gukin', '7Xht:', 'tnli Au3*', "4ak [ 4xi' sa-m", '7o-Cina', '7r>', '1', '6111+0;', 'AAUS', '3*7nn', ':Xjnet', '74889:', '#xsk ,', '4n>A:}', 'KxnkA', 'at', '##AF', '4e3p4t6', '~LJe8c', '#*488i4', '8', '7otl', 'Clctitd', 'jile', 'Feihan', 'Jitt', 'es', 'Koiolmin', '2CC', 'bunh rhon', '~xin', '4milrnd', '"junxx*', '1', 'LecNe', 'Ahhin', '1', 'Rtrr', 'AAden', '4y', 'TK', 'c', '47', 'Juad', 'Lut', '74dn', '"0Mt -', 'Cae', '31~', 'Otnt', '{7*2', "tuiari'", 'at"', 'pnanle', 'I7t5', 'ce', '8el;ct "']
