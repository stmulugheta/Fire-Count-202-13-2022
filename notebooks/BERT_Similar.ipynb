# %% [markdown]
# https://towardsdatascience.com/bert-for-measuring-text-similarity-eec91c6bf9e1

# %%
from transformers import AutoTokenizer, AutoModel
import torch
import pandas as pd
import scipy
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity

pd.set_option('display.max_rows', None)
pd.set_option('max_colwidth', 100)

# %%
data_df = pd.read_csv("fb62e200-0fa3-11ec-82a8-0242ac130003_topics.csv")

# %%
data_df = data_df[data_df['Topics'].notna()]data_df = data_df[data_df['Topics'].notna()]

# %%
kpi_df = pd.read_csv("GRI KPI list.csv")

# %%
model_name = 'sentence-transformers/all-distilroberta-v1'

# %%
model_name = "nbroad/ESG-BERT"

# %%
class BertSim:
    
    def __init__(self, sent_data : list, kpi_data : list, model_name : str, max_length = 32):
        self.tokens = {'input_ids': [], 'attention_mask': []}
        self.data = kpi_data + sent_data
        self.kpi_length = len(kpi_data)
        self.max_length = max_length
        self.tokenizer = AutoTokenizer.from_pretrained(model_name)
        self.model = AutoModel.from_pretrained(model_name)
        self.__initTokens__()
        
    def __initTokens__(self):
        for sentence in self.data:
            # encode each sentence and append to dictionary
            new_tokens = self.tokenizer.encode_plus(sentence, max_length = self.max_length,
                                               truncation=True, padding='max_length',
                                               return_tensors='pt')
            self.tokens['input_ids'].append(new_tokens['input_ids'][0])
            self.tokens['attention_mask'].append(new_tokens['attention_mask'][0])

        # reformat list of tensors into single tensor
        self.tokens['input_ids'] = torch.stack(self.tokens['input_ids'])
        self.tokens['attention_mask'] = torch.stack(self.tokens['attention_mask'])
        
    def __getDenseVectors__(self, embeddings : torch.Tensor) -> np.ndarray:
        attention_mask = self.tokens['attention_mask']
        mask = attention_mask.unsqueeze(-1).expand(embeddings.size()).float()
        masked_embeddings = embeddings * mask
        summed = torch.sum(masked_embeddings, 1)
        summed_mask = torch.clamp(mask.sum(1), min=1e-9)
        mean_pooled = summed / summed_mask
        mean_pooled = mean_pooled.detach().numpy()
        return mean_pooled
        
    def getEmbeddings(self) -> torch.Tensor:
        outputs = self.model(**self.tokens)
        embeddings = outputs.last_hidden_state
        return embeddings
    
    def getSimilarityData(self):
        embeddings = self.getEmbeddings()
        mean_pooled = self.__getDenseVectors__(embeddings)
        sims = cosine_similarity(
            mean_pooled[self.kpi_length:],
            mean_pooled[:self.kpi_length]
        )
        return sims
    
    def getSimilarityDataFrame(self):
        sims = self.getSimilarityData()
        sim_data = [sim.argmax() for sim in sims]
        df = pd.DataFrame()
        df["sentences"] = self.data[self.kpi_length:]
        df["KPI"] = [self.data[i] for i in sim_data]
        return df

# %%
sim = BertSim(list(data_df["sentences"]), list(kpi_df["KPI"]), model_name, 64)
# Out:
# Some weights of the model checkpoint at nbroad/ESG-BERT were not used when initializing BertModel: ['classifier.weight', 'classifier.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
sim_df = sim.getSimilarityDataFrame()

# %%
sim_df.to_csv("ESG_BERT_Sim.csv")

# %%
sim_df
# Out:
#                                                                                               sentences  \
# 0   putting the growth of nations back on track will require a sustained effort over time, and also ...
# 1   during these months in which our attention has been focussed on peoples health, the challenges o...
# 2   this figure supposes more than 80 times the_emissions we needed to produce and purify more than ...
# 3   in 2020, more than eight out of every ten euros invested by acciona businesses financed projects...
# 4   technologies integrated in acciona projects that have allowed us to increase our positive impact...
# 5   making them central to our decisions has been a priority in the cycle now coming to an end, and ...
# 6   in this financial year some of the measures we have adopted have included flexible working days ...
# 7   sor pant an = 11 report 2020 index 1 letter from the chairman 2 the first company of a new secto...
# 8   acciona has been designated a sustainability leader in the sector by s&p global, has received fr...
# 9   from the outset we have maintained a proactive and preventive approach, working hand in hand wit...
# 10  in addition to the necessary measures of flexibility and remote working, almost 40,000 voluntary...
# 11  with specific actions, helping to build field hospi- tals, strengthening the resources of health...
# 12  a. so te sr es aii __ an oe ees i st in i we are embarking on a new cycle, in a new context in w...
# 13  in circumstances like this, it is not enough merely to try to avoid the negative impacts of our ...
# 14  this means establishing a relationship of regeneration between technological progress and the ec...
# 15  sor pant an = 11 report 2020 index 1 letter from the chairman 2 the first company of a new secto...
# 16  ; a letter from the chairman degree of fulfilment of commitments people centric planet positive ...
# 17  8 4 \ os remaining at the forefront by contributing innovative solutions energy ry) a ct: \ /;;,...
# 18  according to recent studies, the development of infrastructure is linked to meeting at least 72%...
# 19  water, energy and transport services are critical in any society, and this has been particularly...
# 20  the company is an expert in the design of a better planet, providing a response to basic infrast...
# 21  activity revenues gross result 40,000 6,472 1,124 orofessionals billion euros billion euros (ebi...
# 22  the problems posed by water, climate change and mega-cities, for example, require new approaches...
# 23  this is why acciona does not see itself as a construction company that has diversified into the ...
# 24  sustainability report ya0yae) index letter from the chairman 2 the first company of a new sector...
# 25  pioneers in sustainable financing products the acciona business model, focussed on sustainabilit...
# 26  the strategic alignment with an investment in sustainable assets can be seen in the analysis tha...
# 27  solutions that can turn traditional projects into assets that multiply their value for the commu...
# 28   @ energy: acciona is the worlds largest energy operator working exclusively with renewable_energy.
# 29  with more than 30 years of experience in the sector, the company owns and operates more than 1og...
# 30  water: acciona is a leader in the water_treatment sector, with the capacity to design, build and...
# 31  the company is addressing the management of waste and the circular economy, is extending electri...
# 32  social: acciona develops infrastructure solutions for health, education and cultural enginee- ri...
# 33  ss more information on accionas business model in the integrated report https:// /shareholders-i...
# 34  o 2 oc 2020 results 10 scconainthevers resulis energy the energy division is a unique global ope...
# 35  the company works exclusively with renewable technologies, with emphasis on five types: wind, ph...
# 36                    it produces clean and emission-free energy for the equivalent of 7 million homes.
# 37  of concessions 22 17 water accionas end-to-end management solutions for the whole water cycle ar...
# 38  its activity focuses on serving communities, ranging from water collection to drinking_water pur...
# 39  it also manages integral services covering all the stages of water_treatment until it is suitabl...
# 40  it supplies water to the population and processes urban and industrial wastewater, directly bill...
# 41    2019 results 2020 results turnover (million ) 758 973 ebitda (million ) 66 84 treated water (hm?)
# 42  1,030 923 sustainability report ya0yae) index letter from the chairman 2 the first company of a ...
# 43  of employees 21,997 20,780 index these include bestinver, a financial services firm that offers ...
# 44  results be renner scecceceeseteeeeseseseseteuscatseseeneeeees ee -bestinver 98 114 degree of ful...
# 45  america and south europe oceania america the first company of a qc eee tee e se ee ree eee ec er...
# 46        & q dominican republic & hungary 4) algeria @ qatar 7 energy business trinidad and tobago @ ?
# 47  businesses portugal ) 008 india united kingdom new zealand 10 ukraine 9 oman @ other businesses ...
# 48  in may 2020, the general shareholders meeting approved the report with the favourable vote of 99...
# 49  functions of the sustainability committee identify and guide the group's policies, objectives, g...
# 50  1 full explanation of the functions, competences and members of the sustainability committee ava...
# 51  in this annual evaluation, the achievement of sustainability targets such as the reduction of gr...
# 52  the smp 2020, which was operative from 2016 to 2020, was structured in strategic and operational...
# 53  degree of compliance with smp 2020 climate change corporate governance smp achievements in the p...
# 54  digitized, transparent and half-yearly non-financial report global diversity and inclusion plan ...
# 55  participation in international forums and initiatives to disseminate our commitment to energy tr...
# 56  detail of the progress > carbon neutrality since 2016 by offsetting_emissions that cannot be red...
# 57  > sbt objective met in a scenario of 1.5c: ghg_emissions reduced by 38% for scopes 1 and 2 and 3...
# 58            > constitution of a decarbonisation fund designed to finance emission reduction measures.
# 59              climate change risk maps designed and drawn up in coordination with the business units.
# 60           plans for adaptation to climate risk drawn up and incorporated into the business strategy.
# 61                         advanced climate change course designed for company employees and suppliers.
# 62  wy environment objectives and commitments improve the efficiency of water_consumption neutral bi...
# 63                        treated in areas with accumulated water_stress in the period of the smp 2020.
# 64                                   > 61% reduction in water_consumption (compared to base year 2017).
# 65                         > 48% of the water used was from recycled, tertiary or rain sources in 2020.
# 66                                                 > biodiversity footprint measurement tool developed.
# 67                  > digitized biodiversity scorecard developed with important measurement indicators.
# 68                                      > public commitment in relation to protected_areas established.
# 69  s296 wea oom one sustainability report ya0yae) index letter from the chairman 2 the first compan...
# 70                                launch of a training course and communication plan for all employees.
# 71  > adoption and execution of the organisation and manage- ment model for crime prevention and ant...
# 72  > dual certification for criminal compliance management system and anti-bribery management syste...
# 73  > formulation of the regulation on the appointments and remuneration committee, regulation on th...
# 74  > tax monitoring framework and reporting of tax informa- tion in the sustainability report, incl...
# 75  > inclusion in the 2020 non-financial information statement of the principal items in the cbc re...
# 76  o objectives and commitment safety: reduce the accident frequency rate by 15% below the figure f...
# 77                                     > analysis and health service surveys in the platform countries.
# 78  > the accionate programme has been implemented throu- ghout the organisation to promote a cultur...
# 79                                                   > approval of global diversity and inclusion plan.
# 80  > the refinitiv diversity & inclusion index has ranked acciona among the one hundred best compan...
# 81  > new programmes implemented to promote gender diversity: global mentoring programme for women i...
# 82  > target to increase the percentage of women in manage- ment positions met, with a figure of 23%...
# 83  > acciona is a signatory of the global compacts womens empowerment principles, and in 2020 signe...
# 84                                    > global gender_equality programme for training of all employees.
# 85  > initiatives launched in projects with the objective of gender parity: loreto project (australi...
# 86  sustainability report ya0yae) index letter from the chairman 2 the first company of a new sector...
# 87                                    training activity at the figure above the european billion euros.
# 88  =e; to develop innovative n b platf nal vad to attract stsrt-ups bet > sustainability courses la...
# 89  deg ree of _ > advance in the implementation of innovative digital tech-eval uid nologies that i...
# 90  sole bor eton wainhi erievotiperats disital inrrewaaert fue, respect, protection and + hunan ris...
# 91  ae > pilot due diligence projects carried out in the infrastructure activities and markets; and ...
# 92                                          people centric > acciona human_rights guide being prepared.
# 93  >h right ls identifi d validated for th;;;;; ume rights controls identined and validated tor the...
# 94                                                 > human_rights training for suppliers and employees.
# 95  5 planet positive objectives and degree of commitment compliance mitigate environmental, social ...
# 96                                                       53 of the 57 macs suppliers have been audited.
# 97    > annual increase in sustainability training for suppliers, up by more than 25% in the last year.
# 98  > criterion of ethical and anti-corruption evaluation of cus- tomers as part of the approval pro...
# 99  million each year) 6 exponential leadership 7 integrate to transform 8 energy business 9 infrast...
#
#                                                                                                     KPI
# 0                             total number of critical concerns communicated to highest governance body
# 1                             total number of critical concerns communicated to highest governance body
# 2                                                                  total water withdrawal in megaliters
# 3                                                               Scope 2 GHG emissions of CO2 equivalent
# 4                                                                             total cooling energy sold
# 5                                                            total monetary value of development grants
# 6                                             number of employees returned to work after parental leave
# 7                                                                            total number of operations
# 8                                                                       revenues from third-party sales
# 9                             total number of critical concerns communicated to highest governance body
# 10                                                number of cases of recordable work-related ill health
# 11         number of fatalities of workers who are not employees as a result of work-related ill health
# 12                                                                      revenues from third-party sales
# 13                                                                     percentage of reclaimed products
# 14                                                                      size of habitat areas protected
# 15                                                                           total number of operations
# 16                                                                      revenues from third-party sales
# 17                                                 percentage of senior management from local community
# 18                                      total number of employees returned to work after parental leave
# 19                                                                              change in water storage
# 20                                                                              total water consumption
# 21                                                                                      operation costs
# 22                            total number of critical concerns communicated to highest governance body
# 23                                                                      revenues from third-party sales
# 24                                                                           total number of operations
# 25                                                                           total number of operations
# 26                                                                                community investments
# 27                                                                                community investments
# 28                                                                 amount of energy consumption reduced
# 29                                                                               total electricity sold
# 30                                                 total third-party water withdrawal with water stress
# 31                                                                       persistent organic pollutants
# 32                                                                      size of habitat areas protected
# 33                                                                           total number of operations
# 34                                                        ratio of energy intensity of the organization
# 35                                                                            total cooling energy sold
# 36                                                                            total heating energy sold
# 37                                                 total third-party water withdrawal with water stress
# 38                                                 total third-party water withdrawal with water stress
# 39                                                                   total third-party water withdrawal
# 40                                                 total third-party water withdrawal with water stress
# 41                                                                   total third-party water withdrawal
# 42                                                                           total number of operations
# 43                                                                      revenues from third-party sales
# 44                                                          corporate income tax accrued on profit/loss
# 45                                                          corporate income tax accrued on profit/loss
# 46                                            percentage of female individuals within governance bodies
# 47                                                                      revenues from third-party sales
# 48                                                          corporate income tax accrued on profit/loss
# 49                                                 percentage of senior management from local community
# 50                                              percentage of male individuals within governance bodies
# 51                                                              Scope 2 GHG emissions of CO2 equivalent
# 52                                                                                community investments
# 53                                                                                community investments
# 54                                percentage of employees per employee category of diversity categories
# 55                                                                                community investments
# 56                                                                               emissions in base year
# 57                                                              co2 equivalent of GHG emissions reduced
# 58                                                                               emissions in base year
# 59                            total number of critical concerns communicated to highest governance body
# 60                                                                                community investments
# 61                                                      Number of suppliers assessed for social impacts
# 62                                                                       persistent organic pollutants
# 63                                                    total produced water withdrawal with water stress
# 64                                                                              total water consumption
# 65                                                                   total third-party water withdrawal
# 66                                                                      size of habitat areas protected
# 67                                                                      size of habitat areas protected
# 68                                                                      size of habitat areas protected
# 69                                                                           total number of operations
# 70                percentage of total employees that received performance and career development review
# 71                             total number/percentage of governance members trained on anti-corruption
# 72                 total number/percentage of anti-corruption policies  communicated to governance body
# 73                                                              total monetary value from tax subsidies
# 74                                                            Corporate income tax paid on a cash basis
# 75                                                            Corporate income tax paid on a cash basis
# 76                                                        rate of fatalities due to work-related injury
# 77                            total number of critical concerns communicated to highest governance body
# 78                                percentage of employees per employee category of diversity categories
# 79                                percentage of employees per employee category of diversity categories
# 80                                percentage of employees per employee category of diversity categories
# 81                                percentage of employees per employee category of diversity categories
# 82                     percentage of female/male individuals within governance bodies over 50 years old
# 83                               Percentage of employees trained in human rights policies or procedures
# 84                                                          total number of permanent female employees
# 85                              total number of investment agreements that include human rights clauses
# 86                                                                           total number of operations
# 87                                    total monetary value received of financial benefits by government
# 88                            total number of critical concerns communicated to highest governance body
# 89  Percentage of operations that have been subject to human rights reviews or human rights impact a...
# 90                                      total number/percentage of employees trained on anti-corruption
# 91                                                            total monetary value of investment grants
# 92                                   Total number of hours devoted to training on human rights policies
# 93                                                                      revenues from third-party sales
# 94                               Percentage of employees trained in human rights policies or procedures
# 95                  Number of suppliers having significant actual and potential negative social impacts
# 96                                 Percentage of new suppliers that were screened using social criteria
# 97                                 Percentage of new suppliers that were screened using social criteria
# 98                 total number/percentage of anti-corruption policies  communicated to governance body
# 99                            total number of critical concerns communicated to highest governance body
